# %% [markdown]
# # **Challenge Overview – Virtual Agent**
#
# Design a smart virtual assistant to help EY professionals quickly access and use internal knowledge, such as documentation, processes, and partner expertise. Your goal is to create an intuitive, AI-powered solution that improves productivity, supports onboarding, and enhances how employees find and apply critical information.
# <br>
# <br>
# ### **Tech & Tools**
#
# It is mandatory to develop the solution in **Google Colab** using **Python** and the **app.py**.
#
# Other than that, you are completely free to choose your own:
#
# •	Libraries and packages: Use any tool you need (e.g., Pandas, Scikit-learn, LangChain, etc.)
#
# •	Visualization tools: Python-based tools (Matplotlib, Seaborn), Power BI, Tableau, etc. (if you use external visualization tools, don't forget to include prints in the submission zip folder)
#
# •	AI assistants: Feel free to consult ChatGPT, GitHub Copilot, Gemini, or any other.
#
# <br>
# <br>
# ### **Tech Configuration**
#
# To speed up the finetuning of the chatbot a dev team already developed:
#
# **1** - Some auxiliary functions normally used in these applications, in app.py;
#
# **2** - A simple connection to a Streamlit Frontend, using google Colab.
#
# Feel free to use, adapt and complement them as needed, or redo them completely to your specifications.
# <br>
# <br>
# ##### **How to Access the app.py Script:**
#
# **1 - Upload the app.py**: Upload app.py to the folder you have this notebook. On Google Colab, upload the script like on the picture bellow
#
# ![image.png](data:image/png;base64,...)
#
# **2 - Open app.py**: Double-click on app.py. This should open the script so you can edit and work on it.
#
# **3** - We suggest using either Gemini or LLaMA as your LLM. Consider your solution’s priorities: Gemini is faster but has context limitations, while LLaMA can handle more context but may be slower.
#
# <br>
#
# ##### **How to Access the Streamlit Frontend:**
#
# **1 - Run the first cell**: This will install the necessary dependencies for the Streamlit app.
#
# **2 - Run the second cell**: This will return an IP address, which is the Google Colab IP.
#
# **3 - Run the third cell**: Click next to the prompt, type 'y', and press Enter.
#
# **4** - After that, a link will be generated. This is the URL where you can access the Streamlit frontend.
#
# **5** - When prompted for a tunnel password, enter the IP address that was returned in the second cell of the notebook.
#
# After that you should be able to visualize the interface of your solution.

# %%
import os

print("Checking the current working directory")
print(os.listdir('.'))
print("---------------------------------------------")
print("Attempting to install the required libraries")
print("---------------------------------------------")
# Run this cell to install the required libraries
# If you need additional libraries, add them
# !pip install streamlit==1.45.1 sentence-transformers==4.1.0 chromadb==1.0.9 pypdf==5.5.0 langchain==0.3.25 langchain-community==0.3.24 langchain-google-genai==2.1.4 torch==2.6.0 torchvision==0.21.0 torchaudio==2.6.0 -q

# %%
# This command fetches and prints the public IPv4 address of the current environment (e.g., Google Colab VM)
# !wget -q -O - ipv4.icanhazip.com

# %%
# This command is used to start streamlit
! streamlit run app.py & npx localtunnel --port 8501
